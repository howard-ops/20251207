# %% [markdown]
# <a href="https://colab.research.google.com/github/howard-ops/20251207/blob/main/20251207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = {"周", "王", "黃", "周"}
#專屬功能 add
name.add("何")
name

#交集 共有的
name2 = {"黃", "謝", "蔡"}
print(name & name2)

#聯集 所有的
print(name | name2)

#減集
print(name - name2)
# Out:
# {'何', '周', '王', '黃'}

# %%
#各種空的
a = []
a = list()
b = {}
b = dict()
c = set()

# %%
import random

lottary = set()
while True:
  n = random.randint(1, 49)
  print(n)
  lottary.add(n)
  if len(lottary) == 6:
    break
print(lottary)
# Out:
# 44
# 28
# 48
# 42
# 7
# 7
# 49
# {7, 42, 44, 48, 49, 28}

# %%
import random

def lottary_creat(low=1, high=49, count=6):

  lottary = set()
  while True:
    n = random.randint(low, high)
    lottary.add(n)
    if len(lottary) == count:
      break
  return lottary

prize = lottary_creat()
#特別號 in
special = None
while True:
  a = random.randint(1, 49)
  if not a in prize:
    special = a
    break
print(prize, special)

#一直買彩券 直到二等(11) 三等(10) 看買幾張
count = 0
score = 0
while True:
  ticket = lottary_creat()
  score = len(ticket & prize) * 2
  if special in ticket:
    score = score + 1
  count = count + 1
  if score >= 11:
    break
print(count, score)
# Out:
# {32, 5, 7, 46, 21, 22} 10
# 1885262 11
